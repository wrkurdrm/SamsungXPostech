# %% [markdown]
# <a href="https://colab.research.google.com/github/wrkurdrm/SamsungXPostech/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 시작

# %%
#넘파이, 판다스 및 필요 라이브러리 호출
import numpy as np
import pandas as pd

#시각화 라이브러리 호출
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
#한글 깨짐 현상을 방지하기 위한 글꼴 설정
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# fonts-nanum is already the newest version (20200506-1).
# 0 upgraded, 0 newly installed, 0 to remove and 16 not upgraded.
# /usr/share/fonts: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 3 dirs
# /usr/share/fonts/truetype/humor-sans: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/truetype/liberation: caching, new cache contents: 16 fonts, 0 dirs
# /usr/share/fonts/truetype/nanum: caching, new cache contents: 12 fonts, 0 dirs
# /usr/local/share/fonts: caching, new cache contents: 0 fonts, 0 dirs
# /root/.local/share/fonts: skipping, no such directory
# /root/.fonts: skipping, no such directory
# /usr/share/fonts/truetype: skipping, looped directory detected
# /usr/share/fonts/truetype/humor-sans: skipping, looped directory detected
# /usr/share/fonts/truetype/liberation: skipping, looped directory detected
# /usr/share/fonts/truetype/nanum: skipping, looped directory detected
# /var/cache/fontconfig: cleaning cache directory
# /root/.cache/fontconfig: not cleaning non-existent cache directory
# /root/.fontconfig: not cleaning non-existent cache directory
# fc-cache: succeeded

# %%
plt.rc('font', family='NanumBarunGothic')

# %%
'''from google.colab import files
myfile = files.upload()'''
# Out:
# 'from google.colab import files\nmyfile = files.upload()'

# %%
dat1=pd.read_excel('/content/(자동차보험) 강설량에 따른 사고율 예측 모델_1.xlsx')
dat1.head()
# Out:
#      사고발생일자  사고발생년도  사고발생월도 지역(시도) 지역(구군) 공휴일구분 주말구분  요일  주차  사고건수
# 0  20170101    2017       1     전남    무안군     Y    Y   7   1    22
# 1  20170101    2017       1     전남    장성군     Y    Y   7   1     3
# 2  20170101    2017       1     인천     중구     Y    Y   7   1    19
# 3  20170101    2017       1     경북    경주시     Y    Y   7   1    35
# 4  20170101    2017       1     경남    통영시     Y    Y   7   1    14

# %%
dat2=pd.read_excel('/content/(자동차보험) 강설량에 따른 사고율 예측 모델_2.xlsx')
dat2.head()
# Out:
#      사고발생일자  사고발생년도  사고발생월도 지역(시도) 지역(구군) 공휴일구분 주말구분  요일  주차  사고건수
# 0  20190701    2019       7     부산    기장군     N    N   1   1    12
# 1  20190701    2019       7     강원    삼척시     N    N   1   1     5
# 2  20190701    2019       7     대구     남구     N    N   1   1    19
# 3  20190701    2019       7     강원    홍천군     N    N   1   1     1
# 4  20190701    2019       7     인천    강화군     N    N   1   1    12

# %%
dat3=pd.read_excel('/content/(자동차보험) 강설량에 따른 사고율 예측 모델_3.xlsx')
dat3.head()
# Out:
#      사고발생일자  사고발생년도  사고발생월도 지역(시도) 지역(구군) 공휴일구분 주말구분  요일  주차  사고건수
# 0  20220101    2022       1     광주    광산구     Y    Y   6   1    17
# 1  20220101    2022       1     경북    성주군     Y    Y   6   1     1
# 2  20220101    2022       1     인천     서구     Y    Y   6   1    41
# 3  20220101    2022       1     부산   해운대구     Y    Y   6   1    21
# 4  20220101    2022       1     충남    논산시     Y    Y   6   1    15

# %%
dat=pd.concat([dat1,dat2,dat3])
dat.head()
# Out:
#      사고발생일자  사고발생년도  사고발생월도 지역(시도) 지역(구군) 공휴일구분 주말구분  요일  주차  사고건수
# 0  20170101    2017       1     전남    무안군     Y    Y   7   1    22
# 1  20170101    2017       1     전남    장성군     Y    Y   7   1     3
# 2  20170101    2017       1     인천     중구     Y    Y   7   1    19
# 3  20170101    2017       1     경북    경주시     Y    Y   7   1    35
# 4  20170101    2017       1     경남    통영시     Y    Y   7   1    14

# %%
dat.tail()
# Out:
#           사고발생일자  사고발생년도  사고발생월도 지역(시도) 지역(구군) 공휴일구분 주말구분  요일  주차  사고건수
# 121005  20230630    2023       6     인천     동구     N    N   5   5     6
# 121006  20230630    2023       6     부산     남구     N    N   5   5     8
# 121007  20230630    2023       6     대구     동구     N    N   5   5    13
# 121008  20230630    2023       6     전남    담양군     N    N   5   5     5
# 121009  20230630    2023       6     충남    서천군     N    N   5   5     3

# %% [markdown]
# # 원본 데이터 사고건수 살펴보기 (5 - num summary)

# %%
Q1, Q2, Q3,Q4 = np.percentile(dat["사고건수"], [25, 50, 75,100])
print(Q1)
print(Q2)
print(Q3)
print(Q4)
# Out:
# 6.0
# 16.0
# 34.0
# 1519.0

# %%
dat['사고건수'].mean()
# Out:
# 24.963706888032416

# %% [markdown]
# # 블랙아이스

# %%
suburb=pd.read_excel('/content/강원충북충남경북경남전북전남제주 일교차습도평균지면온도_설명생략.xlsx')
suburb.head()
# Out:
#       사고발생일자 지역(시도)  평균최저기온(℃)        일교차  평균습도(%rh)    평균지면온도
# 0 2017-01-01     강원  -1.066667   7.566667  69.666667  0.342857
# 1 2017-01-02     강원   1.433333   7.500000  70.333333  1.785714
# 2 2017-01-03     강원  -1.800000  10.400000  59.333333  0.957143
# 3 2017-01-04     강원  -1.066667  10.433333  61.666667  1.292857
# 4 2017-01-05     강원  -1.933333   8.033333  75.666667  0.614286

# %%
urban=pd.read_excel('/content/서울부산대구인천광주대전울산경기세종 일교차습도평균지면온도.xlsx')
urban.head()
# Out:
#       사고발생일자 지역(시도)  최저기온(℃)   일교차  평균습도(%rh)  평균지면온도
# 0 2017-01-01     서울     -1.6  ,8.5       75.9     0.9
# 1 2017-01-02     서울      1.8  ,7.4       77.8     4.8
# 2 2017-01-03     서울     -2.3   ,10       61.8     1.5
# 3 2017-01-04     서울      1.0  ,7.9       55.0     3.0
# 4 2017-01-05     서울     -0.1  ,7.4       52.3     2.4

# %%
urban.rename(columns={'최저기온(℃)':'평균최저기온(℃)'},inplace=True) #칼럼명 통일하여 오류 방지
urban.head()
# Out:
#       사고발생일자 지역(시도)  평균최저기온(℃)   일교차  평균습도(%rh)  평균지면온도
# 0 2017-01-01     서울       -1.6  ,8.5       75.9     0.9
# 1 2017-01-02     서울        1.8  ,7.4       77.8     4.8
# 2 2017-01-03     서울       -2.3   ,10       61.8     1.5
# 3 2017-01-04     서울        1.0  ,7.9       55.0     3.0
# 4 2017-01-05     서울       -0.1  ,7.4       52.3     2.4

# %%
blackice=pd.concat([suburb,urban])
blackice
# Out:
#           사고발생일자 지역(시도)  평균최저기온(℃)        일교차  평균습도(%rh)    평균지면온도
# 0     2017-01-01     강원  -1.066667   7.566667  69.666667  0.342857
# 1     2017-01-02     강원   1.433333        7.5  70.333333  1.785714
# 2     2017-01-03     강원  -1.800000       10.4  59.333333  0.957143
# 3     2017-01-04     강원  -1.066667  10.433333  61.666667  1.292857
# 4     2017-01-05     강원  -1.933333   8.033333  75.666667  0.614286
# ...          ...    ...        ...        ...        ...       ...
# 21039 2023-08-29     세종  21.400000       ,6.3  89.100000       NaN
# 21040 2023-08-30     세종  20.200000       ,2.9  95.100000       NaN
# 21041 2023-08-31     세종  19.800000       ,8.2  84.400000       NaN
# 21042 2023-09-01     세종  18.300000      ,11.2  81.400000       NaN
# 21043 2023-09-02     세종  18.100000        ,13  75.000000       NaN
#
# [40532 rows x 6 columns]

# %%
dat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 526188 entries, 0 to 121009
# Data columns (total 10 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   사고발생일자  526188 non-null  int64
#  1   사고발생년도  526188 non-null  int64
#  2   사고발생월도  526188 non-null  int64
#  3   지역(시도)  526188 non-null  object
#  4   지역(구군)  526188 non-null  object
#  5   공휴일구분   526188 non-null  object
#  6   주말구분    526188 non-null  object
#  7   요일      526188 non-null  int64
#  8   주차      526188 non-null  int64
#  9   사고건수    526188 non-null  int64
# dtypes: int64(6), object(4)
# memory usage: 44.2+ MB

# %%
blackice.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 40532 entries, 0 to 21043
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   사고발생일자     40532 non-null  datetime64[ns]
#  1   지역(시도)     40532 non-null  object
#  2   평균최저기온(℃)  19488 non-null  float64
#  3   일교차        40532 non-null  object
#  4   평균습도(%rh)  40524 non-null  float64
#  5   평균지면온도     38681 non-null  float64
#  6   최저기온(℃)    21040 non-null  float64
# dtypes: datetime64[ns](1), float64(4), object(2)
# memory usage: 2.5+ MB

# %% [markdown]
# 사고발생일자 데이터 형식을 맞춰 오류를 방지한다.

# %%
dat['사고발생일자'] = dat['사고발생일자'].apply(lambda x: pd.to_datetime(str(x), format='%Y-%m-%d'))
dat
# Out:
#            사고발생일자  사고발생년도  사고발생월도 지역(시도) 지역(구군) 공휴일구분 주말구분  요일  주차  사고건수
# 0      2017-01-01    2017       1     전남    무안군     Y    Y   7   1    22
# 1      2017-01-01    2017       1     전남    장성군     Y    Y   7   1     3
# 2      2017-01-01    2017       1     인천     중구     Y    Y   7   1    19
# 3      2017-01-01    2017       1     경북    경주시     Y    Y   7   1    35
# 4      2017-01-01    2017       1     경남    통영시     Y    Y   7   1    14
# ...           ...     ...     ...    ...    ...   ...  ...  ..  ..   ...
# 121005 2023-06-30    2023       6     인천     동구     N    N   5   5     6
# 121006 2023-06-30    2023       6     부산     남구     N    N   5   5     8
# 121007 2023-06-30    2023       6     대구     동구     N    N   5   5    13
# 121008 2023-06-30    2023       6     전남    담양군     N    N   5   5     5
# 121009 2023-06-30    2023       6     충남    서천군     N    N   5   5     3
#
# [526188 rows x 10 columns]

# %%
dat
# Out:
#           사고발생일자  사고발생년도  사고발생월도 지역(시도) 지역(구군) 공휴일구분 주말구분  요일  주차  사고건수
# 0       20170101    2017       1     전남    무안군     Y    Y   7   1    22
# 1       20170101    2017       1     전남    장성군     Y    Y   7   1     3
# 2       20170101    2017       1     인천     중구     Y    Y   7   1    19
# 3       20170101    2017       1     경북    경주시     Y    Y   7   1    35
# 4       20170101    2017       1     경남    통영시     Y    Y   7   1    14
# ...          ...     ...     ...    ...    ...   ...  ...  ..  ..   ...
# 121005  20230630    2023       6     인천     동구     N    N   5   5     6
# 121006  20230630    2023       6     부산     남구     N    N   5   5     8
# 121007  20230630    2023       6     대구     동구     N    N   5   5    13
# 121008  20230630    2023       6     전남    담양군     N    N   5   5     5
# 121009  20230630    2023       6     충남    서천군     N    N   5   5     3
#
# [526188 rows x 10 columns]
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(dat, *['사고발생일자'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(dat, *['사고발생년도'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(dat, *['사고발생월도'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(dat, *['요일'], **{})
# chart
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(dat, *['사고발생일자'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(dat, *['사고발생년도'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(dat, *['사고발생월도'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(dat, *['요일'], **{})
# chart
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def categorical_histogram(df, colname, figscale=1, mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   df.groupby(colname).size().plot(kind='barh', color=sns.palettes.mpl_palette(mpl_palette_name), figsize=(8*figscale, 4.8*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = categorical_histogram(dat, *['공휴일구분'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def categorical_histogram(df, colname, figscale=1, mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   df.groupby(colname).size().plot(kind='barh', color=sns.palettes.mpl_palette(mpl_palette_name), figsize=(8*figscale, 4.8*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = categorical_histogram(dat, *['주말구분'], **{})
# chart
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def scatter_plots(df, colname_pairs, figscale=1, alpha=.8):
#   from matplotlib import pyplot as plt
#   plt.figure(figsize=(len(colname_pairs) * 6 * figscale, 6 * figscale))
#   for plot_i, (x_colname, y_colname) in enumerate(colname_pairs, start=1):
#     ax = plt.subplot(1, len(colname_pairs), plot_i)
#     df.plot(kind='scatter', x=x_colname, y=y_colname, s=(32 * figscale), alpha=alpha, ax=ax)
#     ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = scatter_plots(dat, *[[['사고발생일자', '사고발생년도'], ['사고발생년도', '사고발생월도'], ['사고발생월도', '요일'], ['요일', '주차']]], **{})
# chart
# <h4 class="colab-quickchart-section-title">2-d categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def heatmap(df, x_colname, y_colname, figscale=1, mpl_palette_name='viridis'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   import pandas as pd
#   plt.subplots(figsize=(8 * figscale, 8 * figscale))
#   df_2dhist = pd.DataFrame({
#       x_label: grp[y_colname].value_counts()
#       for x_label, grp in df.groupby(x_colname)
#   })
#   sns.heatmap(df_2dhist, cmap=mpl_palette_name)
#   plt.xlabel(x_colname)
#   plt.ylabel(y_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = heatmap(dat, *['공휴일구분', '주말구분'], **{})
# chart
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def violin_plot(df, value_colname, facet_colname, figscale=1, mpl_palette_name='Dark2', **kwargs):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   figsize = (12 * figscale, 1.2 * figscale * len(df[facet_colname].unique()))
#   plt.figure(figsize=figsize)
#   sns.violinplot(df, x=value_colname, y=facet_colname, palette=mpl_palette_name, **kwargs)
#   sns.despine(top=True, right=True, bottom=True, left=True)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = violin_plot(dat, *['사고발생일자', '공휴일구분'], **{'inner': 'box'})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def violin_plot(df, value_colname, facet_colname, figscale=1, mpl_palette_name='Dark2', **kwargs):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   figsize = (12 * figscale, 1.2 * figscale * len(df[facet_colname].unique()))
#   plt.figure(figsize=figsize)
#   sns.violinplot(df, x=value_colname, y=facet_colname, palette=mpl_palette_name, **kwargs)
#   sns.despine(top=True, right=True, bottom=True, left=True)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = violin_plot(dat, *['사고발생일자', '주말구분'], **{'inner': 'box'})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def violin_plot(df, value_colname, facet_colname, figscale=1, mpl_palette_name='Dark2', **kwargs):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   figsize = (12 * figscale, 1.2 * figscale * len(df[facet_colname].unique()))
#   plt.figure(figsize=figsize)
#   sns.violinplot(df, x=value_colname, y=facet_colname, palette=mpl_palette_name, **kwargs)
#   sns.despine(top=True, right=True, bottom=True, left=True)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = violin_plot(dat, *['사고발생년도', '공휴일구분'], **{'inner': 'box'})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def violin_plot(df, value_colname, facet_colname, figscale=1, mpl_palette_name='Dark2', **kwargs):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   figsize = (12 * figscale, 1.2 * figscale * len(df[facet_colname].unique()))
#   plt.figure(figsize=figsize)
#   sns.violinplot(df, x=value_colname, y=facet_colname, palette=mpl_palette_name, **kwargs)
#   sns.despine(top=True, right=True, bottom=True, left=True)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = violin_plot(dat, *['사고발생년도', '주말구분'], **{'inner': 'box'})
# chart
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def time_series_multiline(df, timelike_colname, value_colname, series_colname, figscale=1, mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   figsize = (10 * figscale, 5.2 * figscale)
#   palette = list(sns.palettes.mpl_palette(mpl_palette_name))
#   def _plot_series(series, series_name, series_index=0):
#     if value_colname == 'count()':
#       counted = (series[timelike_colname]
#                  .value_counts()
#                  .reset_index(name='counts')
#                  .rename({'index': timelike_colname}, axis=1)
#                  .sort_values(timelike_colname, ascending=True))
#       xs = counted[timelike_colname]
#       ys = counted['counts']
#     else:
#       xs = series[timelike_colname]
#       ys = series[value_colname]
#     plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
#   fig, ax = plt.subplots(figsize=figsize, layout='constrained')
#   df = df.sort_values(timelike_colname, ascending=True)
#   if series_colname:
#     for i, (series_name, series) in enumerate(df.groupby(series_colname)):
#       _plot_series(series, series_name, i)
#     fig.legend(title=series_colname, bbox_to_anchor=(1, 1), loc='upper left')
#   else:
#     _plot_series(df, '')
#   sns.despine(fig=fig, ax=ax)
#   plt.xlabel(timelike_colname)
#   plt.ylabel(value_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = time_series_multiline(dat, *['사고발생일자', '사고발생월도', '공휴일구분'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def time_series_multiline(df, timelike_colname, value_colname, series_colname, figscale=1, mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   figsize = (10 * figscale, 5.2 * figscale)
#   palette = list(sns.palettes.mpl_palette(mpl_palette_name))
#   def _plot_series(series, series_name, series_index=0):
#     if value_colname == 'count()':
#       counted = (series[timelike_colname]
#                  .value_counts()
#                  .reset_index(name='counts')
#                  .rename({'index': timelike_colname}, axis=1)
#                  .sort_values(timelike_colname, ascending=True))
#       xs = counted[timelike_colname]
#       ys = counted['counts']
#     else:
#       xs = series[timelike_colname]
#       ys = series[value_colname]
#     plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
#   fig, ax = plt.subplots(figsize=figsize, layout='constrained')
#   df = df.sort_values(timelike_colname, ascending=True)
#   if series_colname:
#     for i, (series_name, series) in enumerate(df.groupby(series_colname)):
#       _plot_series(series, series_name, i)
#     fig.legend(title=series_colname, bbox_to_anchor=(1, 1), loc='upper left')
#   else:
#     _plot_series(df, '')
#   sns.despine(fig=fig, ax=ax)
#   plt.xlabel(timelike_colname)
#   plt.ylabel(value_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = time_series_multiline(dat, *['사고발생일자', '사고발생월도', '주말구분'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def time_series_multiline(df, timelike_colname, value_colname, series_colname, figscale=1, mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   figsize = (10 * figscale, 5.2 * figscale)
#   palette = list(sns.palettes.mpl_palette(mpl_palette_name))
#   def _plot_series(series, series_name, series_index=0):
#     if value_colname == 'count()':
#       counted = (series[timelike_colname]
#                  .value_counts()
#                  .reset_index(name='counts')
#                  .rename({'index': timelike_colname}, axis=1)
#                  .sort_values(timelike_colname, ascending=True))
#       xs = counted[timelike_colname]
#       ys = counted['counts']
#     else:
#       xs = series[timelike_colname]
#       ys = series[value_colname]
#     plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
#   fig, ax = plt.subplots(figsize=figsize, layout='constrained')
#   df = df.sort_values(timelike_colname, ascending=True)
#   if series_colname:
#     for i, (series_name, series) in enumerate(df.groupby(series_colname)):
#       _plot_series(series, series_name, i)
#     fig.legend(title=series_colname, bbox_to_anchor=(1, 1), loc='upper left')
#   else:
#     _plot_series(df, '')
#   sns.despine(fig=fig, ax=ax)
#   plt.xlabel(timelike_colname)
#   plt.ylabel(value_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = time_series_multiline(dat, *['사고발생일자', '요일', '공휴일구분'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def time_series_multiline(df, timelike_colname, value_colname, series_colname, figscale=1, mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   figsize = (10 * figscale, 5.2 * figscale)
#   palette = list(sns.palettes.mpl_palette(mpl_palette_name))
#   def _plot_series(series, series_name, series_index=0):
#     if value_colname == 'count()':
#       counted = (series[timelike_colname]
#                  .value_counts()
#                  .reset_index(name='counts')
#                  .rename({'index': timelike_colname}, axis=1)
#                  .sort_values(timelike_colname, ascending=True))
#       xs = counted[timelike_colname]
#       ys = counted['counts']
#     else:
#       xs = series[timelike_colname]
#       ys = series[value_colname]
#     plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
#   fig, ax = plt.subplots(figsize=figsize, layout='constrained')
#   df = df.sort_values(timelike_colname, ascending=True)
#   if series_colname:
#     for i, (series_name, series) in enumerate(df.groupby(series_colname)):
#       _plot_series(series, series_name, i)
#     fig.legend(title=series_colname, bbox_to_anchor=(1, 1), loc='upper left')
#   else:
#     _plot_series(df, '')
#   sns.despine(fig=fig, ax=ax)
#   plt.xlabel(timelike_colname)
#   plt.ylabel(value_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = time_series_multiline(dat, *['사고발생일자', '요일', '주말구분'], **{})
# chart

# %%
blackice
# Out:
#           사고발생일자 지역(시도)  평균최저기온(℃)        일교차  평균습도(%rh)    평균지면온도  최저기온(℃)
# 0     2017-01-01     강원  -1.066667   7.566667  69.666667  0.342857      NaN
# 1     2017-01-02     강원   1.433333        7.5  70.333333  1.785714      NaN
# 2     2017-01-03     강원  -1.800000       10.4  59.333333  0.957143      NaN
# 3     2017-01-04     강원  -1.066667  10.433333  61.666667  1.292857      NaN
# 4     2017-01-05     강원  -1.933333   8.033333  75.666667  0.614286      NaN
# ...          ...    ...        ...        ...        ...       ...      ...
# 21039 2023-08-29     세종        NaN       ,6.3  89.100000       NaN     21.4
# 21040 2023-08-30     세종        NaN       ,2.9  95.100000       NaN     20.2
# 21041 2023-08-31     세종        NaN       ,8.2  84.400000       NaN     19.8
# 21042 2023-09-01     세종        NaN      ,11.2  81.400000       NaN     18.3
# 21043 2023-09-02     세종        NaN        ,13  75.000000       NaN     18.1
#
# [40532 rows x 7 columns]
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(blackice, *['평균최저기온(℃)'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(blackice, *['평균습도(%rh)'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(blackice, *['평균지면온도'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(blackice, *['최저기온(℃)'], **{})
# chart
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(blackice, *['평균최저기온(℃)'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(blackice, *['평균습도(%rh)'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(blackice, *['평균지면온도'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(blackice, *['최저기온(℃)'], **{})
# chart
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def scatter_plots(df, colname_pairs, figscale=1, alpha=.8):
#   from matplotlib import pyplot as plt
#   plt.figure(figsize=(len(colname_pairs) * 6 * figscale, 6 * figscale))
#   for plot_i, (x_colname, y_colname) in enumerate(colname_pairs, start=1):
#     ax = plt.subplot(1, len(colname_pairs), plot_i)
#     df.plot(kind='scatter', x=x_colname, y=y_colname, s=(32 * figscale), alpha=alpha, ax=ax)
#     ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = scatter_plots(blackice, *[[['평균최저기온(℃)', '평균습도(%rh)'], ['평균습도(%rh)', '평균지면온도'], ['평균지면온도', '최저기온(℃)']]], **{})
# chart
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def time_series_multiline(df, timelike_colname, value_colname, series_colname, figscale=1, mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   figsize = (10 * figscale, 5.2 * figscale)
#   palette = list(sns.palettes.mpl_palette(mpl_palette_name))
#   def _plot_series(series, series_name, series_index=0):
#     if value_colname == 'count()':
#       counted = (series[timelike_colname]
#                  .value_counts()
#                  .reset_index(name='counts')
#                  .rename({'index': timelike_colname}, axis=1)
#                  .sort_values(timelike_colname, ascending=True))
#       xs = counted[timelike_colname]
#       ys = counted['counts']
#     else:
#       xs = series[timelike_colname]
#       ys = series[value_colname]
#     plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
#   fig, ax = plt.subplots(figsize=figsize, layout='constrained')
#   df = df.sort_values(timelike_colname, ascending=True)
#   if series_colname:
#     for i, (series_name, series) in enumerate(df.groupby(series_colname)):
#       _plot_series(series, series_name, i)
#     fig.legend(title=series_colname, bbox_to_anchor=(1, 1), loc='upper left')
#   else:
#     _plot_series(df, '')
#   sns.despine(fig=fig, ax=ax)
#   plt.xlabel(timelike_colname)
#   plt.ylabel(value_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = time_series_multiline(blackice, *['사고발생일자', '평균최저기온(℃)', None], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def time_series_multiline(df, timelike_colname, value_colname, series_colname, figscale=1, mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   figsize = (10 * figscale, 5.2 * figscale)
#   palette = list(sns.palettes.mpl_palette(mpl_palette_name))
#   def _plot_series(series, series_name, series_index=0):
#     if value_colname == 'count()':
#       counted = (series[timelike_colname]
#                  .value_counts()
#                  .reset_index(name='counts')
#                  .rename({'index': timelike_colname}, axis=1)
#                  .sort_values(timelike_colname, ascending=True))
#       xs = counted[timelike_colname]
#       ys = counted['counts']
#     else:
#       xs = series[timelike_colname]
#       ys = series[value_colname]
#     plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
#   fig, ax = plt.subplots(figsize=figsize, layout='constrained')
#   df = df.sort_values(timelike_colname, ascending=True)
#   if series_colname:
#     for i, (series_name, series) in enumerate(df.groupby(series_colname)):
#       _plot_series(series, series_name, i)
#     fig.legend(title=series_colname, bbox_to_anchor=(1, 1), loc='upper left')
#   else:
#     _plot_series(df, '')
#   sns.despine(fig=fig, ax=ax)
#   plt.xlabel(timelike_colname)
#   plt.ylabel(value_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = time_series_multiline(blackice, *['사고발생일자', '평균습도(%rh)', None], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def time_series_multiline(df, timelike_colname, value_colname, series_colname, figscale=1, mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   figsize = (10 * figscale, 5.2 * figscale)
#   palette = list(sns.palettes.mpl_palette(mpl_palette_name))
#   def _plot_series(series, series_name, series_index=0):
#     if value_colname == 'count()':
#       counted = (series[timelike_colname]
#                  .value_counts()
#                  .reset_index(name='counts')
#                  .rename({'index': timelike_colname}, axis=1)
#                  .sort_values(timelike_colname, ascending=True))
#       xs = counted[timelike_colname]
#       ys = counted['counts']
#     else:
#       xs = series[timelike_colname]
#       ys = series[value_colname]
#     plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
#   fig, ax = plt.subplots(figsize=figsize, layout='constrained')
#   df = df.sort_values(timelike_colname, ascending=True)
#   if series_colname:
#     for i, (series_name, series) in enumerate(df.groupby(series_colname)):
#       _plot_series(series, series_name, i)
#     fig.legend(title=series_colname, bbox_to_anchor=(1, 1), loc='upper left')
#   else:
#     _plot_series(df, '')
#   sns.despine(fig=fig, ax=ax)
#   plt.xlabel(timelike_colname)
#   plt.ylabel(value_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = time_series_multiline(blackice, *['사고발생일자', '평균지면온도', None], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def time_series_multiline(df, timelike_colname, value_colname, series_colname, figscale=1, mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   figsize = (10 * figscale, 5.2 * figscale)
#   palette = list(sns.palettes.mpl_palette(mpl_palette_name))
#   def _plot_series(series, series_name, series_index=0):
#     if value_colname == 'count()':
#       counted = (series[timelike_colname]
#                  .value_counts()
#                  .reset_index(name='counts')
#                  .rename({'index': timelike_colname}, axis=1)
#                  .sort_values(timelike_colname, ascending=True))
#       xs = counted[timelike_colname]
#       ys = counted['counts']
#     else:
#       xs = series[timelike_colname]
#       ys = series[value_colname]
#     plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
#   fig, ax = plt.subplots(figsize=figsize, layout='constrained')
#   df = df.sort_values(timelike_colname, ascending=True)
#   if series_colname:
#     for i, (series_name, series) in enumerate(df.groupby(series_colname)):
#       _plot_series(series, series_name, i)
#     fig.legend(title=series_colname, bbox_to_anchor=(1, 1), loc='upper left')
#   else:
#     _plot_series(df, '')
#   sns.despine(fig=fig, ax=ax)
#   plt.xlabel(timelike_colname)
#   plt.ylabel(value_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = time_series_multiline(blackice, *['사고발생일자', '최저기온(℃)', None], **{})
# chart

# %%
merged_df=pd.merge(dat,blackice,how='inner')
merged_df
# Out:
#            사고발생일자  사고발생년도  사고발생월도 지역(시도) 지역(구군) 공휴일구분 주말구분  요일  주차  사고건수  \
# 0      2017-01-01    2017       1     전남    무안군     Y    Y   7   1    22
# 1      2017-01-01    2017       1     전남    장성군     Y    Y   7   1     3
# 2      2017-01-01    2017       1     전남    완도군     Y    Y   7   1     4
# 3      2017-01-01    2017       1     전남    강진군     Y    Y   7   1     1
# 4      2017-01-01    2017       1     전남    나주시     Y    Y   7   1    13
# ...           ...     ...     ...    ...    ...   ...  ...  ..  ..   ...
# 525303 2023-06-30    2023       6     대전    대덕구     N    N   5   5    17
# 525304 2023-06-30    2023       6     대전     중구     N    N   5   5    15
# 525305 2023-06-30    2023       6     대전    유성구     N    N   5   5    37
# 525306 2023-06-30    2023       6     대전     서구     N    N   5   5    57
# 525307 2023-06-30    2023       6     대전     동구     N    N   5   5    18
#
#         평균최저기온(℃)   일교차  평균습도(%rh)     평균지면온도
# 0            -0.3  11.6       81.0   3.946154
# 1            -0.3  11.6       81.0   3.946154
# 2            -0.3  11.6       81.0   3.946154
# 3            -0.3  11.6       81.0   3.946154
# 4            -0.3  11.6       81.0   3.946154
# ...           ...   ...        ...        ...
# 525303       22.9  ,3.2       90.5  26.000000
# 525304       22.9  ,3.2       90.5  26.000000
# 525305       22.9  ,3.2       90.5  26.000000
# 525306       22.9  ,3.2       90.5  26.000000
# 525307       22.9  ,3.2       90.5  26.000000
#
# [525308 rows x 14 columns]

# %%
sns.heatmap(merged_df.corr(),annot=True,cmap='RdYlGn',linewidths=0.2)
fig=plt.gcf()
fig.set_size_inches(10,8)
plt.show()

# %%
snow=pd.read_excel('/content/강설량통합데이터.xlsx')
snow.head()
# Out:
#      연도   날짜  지점       기상현상  일 최심신적설(cm)
# 0  2017  105  경북  진눈깨비  싸락눈          NaN
# 1  2017  109  경북       진눈깨비          NaN
# 2  2017  110  수원          눈          NaN
# 3  2017  110  경북        소낙눈          NaN
# 4  2017  110  인천          눈          NaN

# %%
X_train, X_test, y_train, y_test = train_test_split(X,

                                                    y,

                                                    test_size=0.3,

                                                    shuffle=False,

                                                    random_state=1004)
